# %%
from matplotlib import category

import Predictor
import matplotlib.pyplot as plt
import pandas as pd
unprocessedData = Predictor.predict(filePath="C:\\Users\\sophi\\Downloads\\activity (4).xlsx")
DescriptorValues = pd.Categorical(unprocessedData["Description"]).as_ordered()
processedData = Predictor.ConvertToValues(unprocessedData)

# %%
# %matplotlib widget
from matplotlib import scale, widgets
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


plt.ion()
# make data: correlated + noise
x = unprocessedData["Description"].values
# x.labels = unprocessedData["Description"]
y = unprocessedData["Amount"].values
# plot:
ax = plt.subplot(1, 1, 1)
ax.set_title('Description vs Amount')
ax.set_xlabel('Description of Purchase')
ax.set_ylabel('Amount in USD')
ax.axes.set_xticks(range(len(DescriptorValues)))
ax.axes.set_xticklabels(DescriptorValues, rotation=90)
ax.axes.set_yticks(range(0, int(max(y)), int(max(y)/len(DescriptorValues)) if len(DescriptorValues) > 0 else 1))
ax.scatter(x, y, c=processedData["Description"].cat.codes, cmap='viridis', s=100)
plt.gcf().set_size_inches(10, 5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
